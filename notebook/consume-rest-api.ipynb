# %%
import requests
from datetime import datetime
import json

# %%
url = "https://rest.vitally.io/resources/users/203620"

headers = {
    "content-type": "application/json",
    "Authorization": "Basic c2tfbGl2ZV9iMDI2M2VhZmM5ZjZmODE0Y2EwNzA2ZGUzOTk1OWYyNDMzZWExY2RmODllZWFiNWQ5ODAzMTI1YzIyYzkzMDMwOg=="
}

response = requests.get(url, headers=headers)

response_dict = json.loads(response.text)
response_dict
# Out:
# {'id': '7f1bc72c-d746-4af6-8573-42dfaef9d666',
#  'createdAt': '2020-11-25T09:32:09.074Z',
#  'updatedAt': '2024-01-15T19:46:10.268Z',
#  'externalId': '203620',
#  'accounts': [{'id': 'bd0694d9-5b20-4adb-9d31-d160b4211fe9',
#    'createdAt': '2020-11-26T02:53:39.544Z',
#    'updatedAt': '2024-01-15T19:45:10.704Z',
#    'externalId': '82088',
#    'name': 'Quadros & Lopes Odontologia',
#    'traits': {'name': 'Quadros & Lopes Odontologia',
#     'email': 'atendimentoquadroselopes@gmail.com',
#     'plano': 'Pago - Gestão',
#     'origem': None,
#     'status': 'Ativa',
#     'linkAdm': 'https://adm.simplesdental.com/#/clinica/82088',
#     'invalida': False,
#     'trialAte': 1585882740000,
#     'createdAt': 1585217178278,
#     'valorPago': 199.9,
#     'dataCompra': 1704153600000,
#     'iDatabases': 72039,
#     'planoAnual': False,
#     'dataPagoAte': 1706832000000,
#     'adimplenteSD': True,
#     'dataBloqueio': 1704412800000,
#     'audCriadoData': None,
#     'dataConversao': 1589822553098,
#     'meioPagamento': 'Cartão de crédito',
#     'dataFaturamento': 1704423981670,
#     'dataInicioTrial': 1585217234089,
#     'recebeuPromoBF2021': True,
#     'upgradeVendasBF2021': True},
#    'organizationId': None,
#    'accountOwnerId': 'ce71fd08-aee9-451d-ba71-a336064e3fa4',
#    'mrr': 199.9,
#    'nextRenewalDate': '2021-02-02T07:00:00.485Z',
#    'churnedAt': None,
#    'firstSeenTimestamp': '2020-11-26T13:29:32.191Z',
#    'lastSeenTimestamp': '2024-01-15T19:40:48.460Z',
#    'lastInboundMessageTimestamp': None,
#    'lastOutboundMessageTimestamp': None,
#    'trialEndDate': '2020-04-03T02:59:00.000Z',
#    'usersCount': 11,
#    'npsDetractorCount': 0,
#    'npsPassiveCount': 0,
#    'npsPromoterCount': 1,
#    'npsScore': 100,
#    'healthScore': 10,
#    'csmId': 'deb45a22-752d-4fb7-9396-fa2373f57c52',
#    'accountExecutiveId': None,
#    'segments': [{'id': '28d3ca61-ee3b-45d5-9d27-d317b99728db',
#      'name': 'Plano Gestão'}]}],
#  'name': 'Priscila Guerra Ramos',
#  'email': 'priscilaguerra05@gmail.com',
#  'avatar': None,
#  'traits': {'name': 'Priscila Guerra Ramos',
#   'role': 'Secretaria',
#   'email': 'priscilaguerra05@gmail.com',
#   'linkAdm': 'https://adm.simplesdental.com/#/clinica/82088',
#   'createdAt': 1594735917089,
#   'iDatabases': 72039},
#  'firstKnown': '2020-07-14T14:11:57.089Z',
#  'lastSeenTimestamp': '2024-01-15T19:40:48.513Z',
#  'lastInboundMessageTimestamp': None,
#  'lastOutboundMessageTimestamp': None,
#  'npsLastScore': None,
#  'npsLastFeedback': None,
#  'npsLastRespondedAt': None,
#  'unsubscribedFromConversations': False,
#  'unsubscribedFromConversationsAt': None,
#  'deactivatedAt': None,
#  'segments': [],
#  'joinDate': '2020-07-14T14:11:57.089Z'}
