# %%
from datetime import timedelta

# %%
def fun_error():
    if len("nome") > 3:
        print("Deu erro 1")
        return None
        # raise Exception("Deu erro 2")
    
    return 1

ret = fun_error()    

if ret is None:
    print("")
else:
    print(f"Nao deu erro")
# Out:
# Deu erro 1
